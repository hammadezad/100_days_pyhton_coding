# %% [markdown]
# ## Printing

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# #### Notes: This is called s string because it has qoutation marks with it

# %% [markdown]
# #### Exercise (Debugging)

# %%
print("Day 1 - String Manipulation")
print('String Concatenation is done with the "+" sign.')
print('e.g. print("Hello " + "world")')
print("New lines can be created with a backslash and n.")
# Out:
# Day 1 - String Manipulation
# String Concatenation is done with the "+" sign.
# e.g. print("Hello " + "world")
# New lines can be created with a backslash and n.

# %% [markdown]
# ## String Manipulation

# %%
#Notes: By putting the "+" sign, we can add two strings in this way

# %%
print("Hello" + " World")
# Out:
# Hello World

# %% [markdown]
# ## Input function

# %%
print("What is your name?")
# Out:
# What is your name?

# %%
input("What is your name?")
# Out:
# What is your name?Hammad
# 'Hammad'

# %%
# It will first take the input from the user and then do print with Hello
print("Hello " + input("What is your name?") + "!")
# Out:
# What is your name?Hammad
# Hello Hammad!

# %% [markdown]
# #### Exercise

# %%
# Write a program that prints the number of characters in a user's name. You might need to Google for a function that calculates the length of a string.

# %%
Name = input("What is your name?")
print(len(Name))
# Out:
# What is your name?Hammad
# 6

# %%
print(len(input("What is your name? ")))
# Out:
# What is your name? Hammad
# 6

# %% [markdown]
# ## Python Variables

# %%
name = "Jack"
print(name)
# Out:
# Jack

# %%
name = "Hammad"
print(name)
# Out:
# Hammad

# %%
name = input("What is your name?")
length = len(name)
print(length)
# Out:
# What is your name?Hammad
# 6

# %% [markdown]
# #### Exercise
# Change in such a way that a becomes b and b becomes a

# %%
a = input("a: ")
b = input("b: ")

c = a
a = b
b = c
print("a: " + a)
print("b: " + b)
# Out:
# a:
# b:
# a:
# b:

# %% [markdown]
# ### Final Exercise

# %%
#1. Create a greeting for your program.

#2. Ask the user for the city that they grew up in.

#3. Ask the user for the name of a pet.

#4. Combine the name of their city and pet and show them their band name.

#5. Make sure the input cursor shows on a new line, see the example at:

# %%
print("Good Morning!")
city = input("In which city you grew up?\n")
pet = input("Whats the name of your pet?\n")
brand_name = city + " " + pet
print("Your brand name could be " + brand_name)
# Out:
# Good Morning!
# In which city you grew up?
# Sahiwal
# Whats the name of your pet?
# Aiwein
# Your brand name could be Sahiwal Aiwein
