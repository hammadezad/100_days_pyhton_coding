# %% [markdown]
# # First day of Python

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Print

# %%
print('Day 1 - Python Print Function')
print('The function is declared like this:')
print("Print('What to print')")
# In this we leart how to use the commas and how they can be very different from one another
# Out:
# Day 1 - Python Print Function
# The function is declared like this:
# Print('What to print')

# %% [markdown]
# ### String Manipulation

# %%
print('Hello World\nHello World\nHello World')
# Out:
# Hello World
# Hello World
# Hello World

# %%
# We can concatenate thee follwing way 
print("Hello" + " " + "Hammad")
# Out:
# Hello Hammad

# %% [markdown]
# ### Debugging

# %%
print("Day 1 - String Manipulation")
# Out:
# Day 1 - String Manipulation

# %% [markdown]
# ### Giving the function of input and commenting

# %%
# Giving the input
print("Hello " + input("Whats your name")+ "!")
# Out:
# Whats your name Hammad
# Hello Hammad!

# %% [markdown]
# ### Exercise

# %%
name = input("Please write you name:")
length = len(name)
print(length)
# Out:
# Please write you name: Hammad
# 6

# %%
print(len(input("Please write you name:")))
# Out:
# Please write you name: Hammad
# 6

# %% [markdown]
# ### Switching the values

# %%
a = input("please write a:")
b = input("please write b:")
c = a
a = b
b = c
print(a)
print(b)
# Out:
# please write a: 3
# please write b: 5
# 5
# 3

# %%
print(a,b)
# Out:
# 3 5

# %% [markdown]
# ### Getting the Band Name Generator

# %%
print("Welcome to the Band Generator Program")
city = input("Which city did you grew up in?\n")
pet = input("What is the name of your pet?\n")
band_name = city + " " + pet
print(band_name)
# Out:
# Welcome to the Band Generator Program
# Which city did you grew up in?
#  Sahiwal
# What is the name of your pet?
#  Kutta
# Sahiwal Kutta
